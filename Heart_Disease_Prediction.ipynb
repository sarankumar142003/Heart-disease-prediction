# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from  imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
heart=pd.read_csv("Heart_Disease_Prediction.csv")

# %%
heart.head(5)
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
heart.shape
# Out:
# (270, 14)

# %%
heart.columns
# Out:
# Index(['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120',
#        'EKG results', 'Max HR', 'Exercise angina', 'ST depression',
#        'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease'],
#       dtype='object')

# %%
heart.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object

# %%
heart.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
heart.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
heart.duplicated().sum()
# Out:
# 0

# %%
heart.groupby("Age")["Age"].count().sort_values(ascending=False).head()
# Out:
# Age
# 54    16
# 58    15
# 51    12
# 57    12
# 59    12
# Name: Age, dtype: int64

# %% [markdown]
# # Lable Encoding

# %%
le=LabelEncoder()
heart["Heart Disease"]=le.fit_transform(heart["Heart Disease"])

# %%
heart.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# ...

# %%
sns.countplot(data=heart , x="Heart Disease")
plt.show()

# %%
heart["Heart Disease"].value_counts()
# Out:
# Heart Disease
# 0    150
# 1    120
# Name: count, dtype: int64

# %%
x=heart.drop("Heart Disease",axis=1)
y=heart["Heart Disease"]

# %% [markdown]
# # smote

# %%
xre,yre=SMOTE(random_state=42).fit_resample(x,y)

# %%
xre.shape,yre.shape
# Out:
# ((300, 13), (300,))

# %% [markdown]
# # training and testing

# %%
x_train,x_test,y_train,y_test=train_test_split(xre,yre, test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((240, 13), (60, 13), (240,), (60,))

# %% [markdown]
# # Random Forest

# %%
random = RandomForestClassifier()

# %%
random.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
ypr=random.predict(x_test)

# %%
accuracy_score(y_test,ypr)
# Out:
# 0.8166666666666667

# %%
print(classification_report(y_test,ypr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.81        31
#            1       0.76      0.90      0.83        29
#
#     accuracy                           0.82        60
#    macro avg       0.82      0.82      0.82        60
# weighted avg       0.83      0.82      0.82        60

# %%
import joblib

# %%
# save
joblib.dump(random,"heart_model.pkl")
# Out:
# ['heart_model.pkl']
